# %%
import sys
from pympler import asizeof

# %% [markdown]
# ### Интерактивная справка в Jupyter-notebook
#
# - вывод всех магических команд

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# ### Сменим кодировку
# Эта команда обязательно должна быть в отдельной ячейке. Не пугайтесь, что её вывод - кракозябры на винде

# %%
# !chcp 1251
# Out:
# ’ҐЄгй п Є®¤®ў п бва ­Ёж : 1251

# %%
# %ls
# Out:
#  Том в устройстве D имеет метку Локальный диск
#  Серийный номер тома: 98BD-5CD1
#
#  Содержимое папки D:\PycharmProjects\jupyter\Изучаем
#
# 02.12.2020  21:02    <DIR>          .
# 02.12.2020  21:02    <DIR>          ..
# 02.12.2020  20:47    <DIR>          .ipynb_checkpoints
# 02.12.2020  20:56           181 439 Some important sfuff.ipynb
# 15.11.2020  22:41    <DIR>          tensorflow
# 02.12.2020  20:56                 9 test.txt
# 23.10.2020  20:47               306 Untitled.ipynb
# 27.11.2020  00:01               555 Untitled1.ipynb
# 11.07.2020  20:49            31 886 Изучаем format.ipynb
# 02.12.2020  21:02            18 134 Изучаем jupyter notebook.ipynb
# 27.11.2020  00:35            40 496 Изучаем Latex.ipynb
# 11.07.2020  20:55           530 580 Изучаем os.walk.ipynb
# 05.09.2020  23:26             1 510 Изучаем threading.ipynb
# 02.12.2020  20:43             4 908 Изучаем вывод в HEX.ipynb
# 30.06.2020  23:54             3 854 Хаффман.ipynb
# ...

# %% [markdown]
# ### Узнать назначение и свойства любого объекта\модуля\класса в python можно с помощью знака `?`

# %%
pprint?

# %%
sys?

# %%
d1 = {"k1":10, "k2":20, "k3":30}
d1?

# %%
# %%HTML?

# %%
# %prun?

# %% [markdown]
# ### Также можно использовать метод `help([object])`. Он даёт больше информации

# %%
d1 = {"k1":10, "k2":20, "k3":30}

help(d1)
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
# ...

# %%
help(dir)
# Out:
# Help on built-in function dir in module builtins:
#
# dir(...)
#     dir([object]) -> list of strings
#
#     If called without an argument, return the names in the current scope.
#     Else, return an alphabetized list of names comprising (some of) the attributes
#     of the given object, and of attributes reachable from it.
#     If the object supplies a method named __dir__, it will be used; otherwise
#     the default dir() logic is used and returns:
#       for a module object: the module's attributes.
#       for a class object:  its attributes, and recursively the attributes
#         of its bases.
#       for any other object: its attributes, its class's attributes, and
#         recursively the attributes of its class's base classes.

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_2',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_exit_code',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'asizeof',
#  'd1',
#  'exit',
#  'get_ipython',
#  'quit',
#  'sys']

# %% [markdown]
# - `dir` без параметров показывает внутреннее состояние интерпретатора. Любую переменную можно вывести

# %%
print(_i1)
print(_i2)
print(_i3)
# Out:
# import sys
# from pympler import asizeof
# %lsmagic
# !chcp 1251

# %% [markdown]
# ### Так можно узнать размер объектов

# %%
print("d1.__sizeof__(d1) {0:7d}".format(d1.__sizeof__()))
print("sys.getsizeof(d1) {0:7d}".format(sys.getsizeof(d1)))
print("asizeof.asizeof(d1) {0:5d}".format(asizeof.asizeof(d1)))
# Out:
# d1.__sizeof__(d1)     216
# sys.getsizeof(d1)     240
# asizeof.asizeof(d1)   504

# %% [markdown]
# ### Вывод содержимого файла

# %%
pycat test.txt

# %% [markdown]
# ### Отображение картинок IPython

# %%
from IPython.display import Image # Библиотека для отображения картинок

display(Image(url='https://habrastorage.org/webt/9m/2c/zd/9m2czdt-uv7oe6v-nws3frtw7-a.jpeg', 
              width = 200) # Задаем ширину картинки
       )
# Out:
# <img src="https://habrastorage.org/webt/9m/2c/zd/9m2czdt-uv7oe6v-nws3frtw7-a.jpeg" width="200"/>

# %%
import IPython.display
dir(IPython.display)
# Out:
# ['Audio',
#  'Code',
#  'DisplayHandle',
#  'DisplayObject',
#  'FileLink',
#  'FileLinks',
#  'GeoJSON',
#  'HTML',
#  'IFrame',
#  'Image',
#  'JSON',
#  'Javascript',
#  'Latex',
#  'Markdown',
#  'Math',
#  'Pretty',
#  'ProgressBar',
#  'SVG',
#  'ScribdDocument',
#  'TextDisplayObject',
#  'Video',
#  'VimeoVideo',
#  'YouTubeVideo',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'clear_output',
#  'display',
#  'display_html',
#  'display_javascript',
#  'display_jpeg',
#  'display_json',
#  'display_latex',
#  'display_markdown',
#  'display_pdf',
#  'display_png',
#  'display_pretty',
#  'display_svg',
#  'publish_display_data',
#  'set_matplotlib_close',
#  'set_matplotlib_formats',
#  'update_display']

# %%
from PIL import Image

img = Image.open("../open-source-logos.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=700x456 at 0x1BC46A0C248>

# %% [markdown]
# ### HTML в Jupyter Notebook

# %%
from IPython.core.display import display, HTML
display(HTML("<font color='green'>Мой зеленый текст</font>"))
# Out:
# <font color='green'>Мой зеленый текст</font>

# %%
from termcolor import colored # Для установки запустите из командной строки pip install termcolor

print(colored("Красный текст (без атрибутов)", "red"))
print(colored("Красный текст (подчеркивание)", "red",  attrs=["underline"]))
print(colored("Зеленый текст на красном фоне (без атрибутов)", "green", "on_red" ))
print(colored("Зеленый текст на красном фоне (bold)", "green", "on_red", attrs=["bold"]))
# Out:
# Красный текст (без атрибутов)
# Красный текст (подчеркивание)
# Зеленый текст на красном фоне (без атрибутов)
# Зеленый текст на красном фоне (bold)
