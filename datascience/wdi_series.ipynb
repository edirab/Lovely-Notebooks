# %%
import pandas as pd
import numpy as np
from pprint import pprint

pd.set_option('max_colwidth', 120)
pd.set_option('display.width', 500)

df = pd.read_csv('world-development-indicators/Series.csv')
print(len(df))
df.head()
# Out:
# 1345
#              SeriesCode                                                                     Topic                                              IndicatorName ShortDefinition                                                                                                           LongDefinition UnitOfMeasure Periodicity BasePeriod  OtherNotes AggregationMethod                                                                                                 LimitationsAndExceptions  \
# 0        BN.KLT.DINV.CD  Economic Policy & Debt: Balance of payments: Capital & financial account          Foreign direct investment, net (BoP, current US$)             NaN  Foreign direct investment are the net inflows of investment to acquire a lasting management interest (10 percent or ...           NaN      Annual        NaN         NaN               NaN                                                                                                                      NaN
# ...
